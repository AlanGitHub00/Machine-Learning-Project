# %% [markdown]
# EX-1 - Mean / Median / STD

# %% [markdown]
# We have some sample salary data (in thousands) from two cities.

# %%
city1 = [15,12, 20, 25, 50, 35, 75, 80, 60, 45, 36]
city2 = [40,42, 45, 60, 55, 52, 56, 52, 62, 57, 48]

# %% [markdown]
# Calculate mean, median, variation, standard deviation for both city data.

# %%
import statistics
x1 = statistics.mean(city1)
print("The mean of city1 is", x1)        #mean for city1
# Out:
# The mean of city1 is 41.18181818181818

# %%
x2 = statistics.mean(city2)
print("The mean of city2 is", x2)    #mean for city2
# Out:
# The mean of city2 is 51.72727272727273

# %%
x3 = statistics.median(city1)
print("The median of city1 is", x3)  #median for city 1
# Out:
# The median of city1 is 36

# %%
x4 = statistics.median(city2)
print("The median of city2 is", x4) #median for city 2
# Out:
# The median of city2 is 52

# %%
import numpy as np
x5 = np.std(city1)
print("The standard deviation of city1 is",x5) #standard deviation of city1
# Out:
# The standard deviation of city1 is 22.176228803990593

# %%
x6 = np.std(city2)
print("The standard deviation of city2 is",x6) #standard deviation of city2
# Out:
# The standard deviation of city2 is 6.889925571453243

# %% [markdown]
# EX-2 - NBA Player Stats

# %% [markdown]
# 1. Read nba player stats data

# %%
import pandas as pd
data_location  = 'nba-player-stats.csv'

player = pd.read_csv(data_location)
print("nba player : ", player.size)
player
# Out:
# nba player :  4122
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
player.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
player.describe(include='all')
# Out:
#                Name                  Team      Number Position         Age  \
# count           457                   457  457.000000      457  457.000000
# unique          457                    30         NaN        5         NaN
# top     Matt Bonner  New Orleans Pelicans         NaN       SG         NaN
# freq              1                    19         NaN      102         NaN
# mean            NaN                   NaN   17.678337      NaN   26.938731
# std             NaN                   NaN   15.966090      NaN    4.404016
# min             NaN                   NaN    0.000000      NaN   19.000000
# 25%             NaN                   NaN    5.000000      NaN   24.000000
# 50%             NaN                   NaN   13.000000      NaN   26.000000
# 75%             NaN                   NaN   25.000000      NaN   30.000000
# max             NaN                   NaN   99.000000      NaN   40.000000
#
#        Height      Weight   College        Salary
# ...

# %%
dropped_na = player['Salary'].dropna()

# %%
dropped_na
# Out:
# 0       7730337.0
# 1       6796117.0
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
#           ...
# 452     2239800.0
# 453     2433333.0
# 454      900000.0
# 455     2900000.0
# 456      947276.0
# Name: Salary, Length: 446, dtype: float64

# %% [markdown]
# 2. Find min/max/mean/median of salary

# %%
player['Salary'].describe()
# Out:
# count    4.460000e+02
# mean     4.842684e+06
# std      5.229238e+06
# min      3.088800e+04
# 25%      1.044792e+06
# 50%      2.839073e+06
# 75%      6.500000e+06
# max      2.500000e+07
# Name: Salary, dtype: float64

# %%
print("The mean of the player's salary is", player['Salary'].mean())
# Out:
# The mean of the player's salary is 4842684.105381166

# %%
print("The median of the player's salary is", player['Salary'].median())
# Out:
# The median of the player's salary is 2839073.0

# %%
print("The maximum salary of the player is", player['Salary'].max())
# Out:
# The maximum salary of the player is 25000000.0

# %%
print("The minimum salary of the player is", player['Salary'].min())
# Out:
# The minimum salary of the player is 30888.0

# %% [markdown]
# 3. Is there a large variance in salary? How will you find out?

# %%
import statistics
x7 = player['Salary'].dropna()

# %%
x7
# Out:
# 0       7730337.0
# 1       6796117.0
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
#           ...
# 452     2239800.0
# 453     2433333.0
# 454      900000.0
# 455     2900000.0
# 456      947276.0
# Name: Salary, Length: 446, dtype: float64

# %%
print("The variance of player's Salary is", statistics.variance(x7))
# Out:
# The variance of player's Salary is 27344925865857.652

# %%
x8 = player['Salary'].mean()
print("The average of the salary of nba player is", x8)
# By comparison, there are very large variance in this dataset
# Out:
# The average of the salary of nba player is 4842684.105381166

# %% [markdown]
# 4. Find the 10% trimmed mean of salary

# %%
import pandas as pd
from scipy.stats import trim_mean
import numpy as np

x9 = trim_mean(player["Salary"].values, 0.1)

# %%
print("The 10% of trimmed mean of salary is", x9)
# Out:
# The 10% of trimmed mean of salary is 4177702.277173913

# %% [markdown]
# 5. Do some plots for salary

# %% [markdown]
# Hint: boxplot and histograms

# %%
player.boxplot(column=['Salary'])

# %%
player.hist(column=['Salary'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001860188A4C0>]],
#       dtype=object)

# %% [markdown]
# EX-3 - Correlation of NBA Player Stats

# %% [markdown]
# 1. Read nba player stats data

# %% [markdown]
# 2. Extract Height and Weight columns

# %%
player['Height'].describe()
# Out:
# count     457
# unique     18
# top       6-9
# freq       59
# Name: Height, dtype: object

# %%
player['Height'].describe(include='all')
# Out:
# count     457
# unique     18
# top       6-9
# freq       59
# Name: Height, dtype: object

# %%
player['Weight'].describe()
# Out:
# count    457.000000
# mean     221.522976
# std       26.368343
# min      161.000000
# 25%      200.000000
# 50%      220.000000
# 75%      240.000000
# max      307.000000
# Name: Weight, dtype: float64

# %%
player['Weight'].describe(include='all')
# Out:
# count    457.000000
# mean     221.522976
# std       26.368343
# min      161.000000
# 25%      200.000000
# 50%      220.000000
# 75%      240.000000
# max      307.000000
# Name: Weight, dtype: float64

# %%
player['Height'].dropna()
# Out:
# 0       6-2
# 1       6-6
# 2       6-5
# 3       6-5
# 4      6-10
#        ...
# 452    6-10
# 453     6-3
# 454     6-1
# 455     7-3
# 456     7-0
# Name: Height, Length: 457, dtype: object

# %%
player['Weight'].dropna()
# Out:
# 0      180.0
# 1      235.0
# 2      205.0
# 3      185.0
# 4      231.0
#        ...
# 452    234.0
# 453    203.0
# 454    179.0
# 455    256.0
# 456    231.0
# Name: Weight, Length: 457, dtype: float64

# %% [markdown]
# 3. You will notice the height is in feet-inches format. For example 6-4. You will need to convert this to single numeric format.

# %%
df = pd.DataFrame(player)
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.dropna()
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df = pd.read_csv('nba-player-stats.csv')

# drop rows with no height data
df = df.dropna(subset=['Height'])     

# split the strings
df.Height = [s.split('-') for s in df.Height]
# convert to inches
df.Height = [float(value[0])*12 + float(value[1]) for value in df.Height]

# write data
df.to_csv('nba-player-stats.csv', index=False)

# %%
df.Height
# Out:
# 0      74.0
# 1      78.0
# 2      77.0
# 3      77.0
# 4      82.0
#        ...
# 452    82.0
# 453    75.0
# 454    73.0
# 455    87.0
# 456    84.0
# Name: Height, Length: 457, dtype: float64

# %%
df
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    74.0   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    78.0   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    77.0   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    77.0   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0    82.0   231.0
# ..             ...             ...     ...      ...   ...     ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0    82.0   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    75.0   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    73.0   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    87.0   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    84.0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df['height_cm'] = df['Height'] * 2.54

# %%
df['height_cm']
# Out:
# 0      187.96
# 1      198.12
# 2      195.58
# 3      195.58
# 4      208.28
#         ...
# 452    208.28
# 453    190.50
# 454    185.42
# 455    220.98
# 456    213.36
# Name: height_cm, Length: 457, dtype: float64

# %%
df
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    74.0   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    78.0   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    77.0   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    77.0   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0    82.0   231.0
# ..             ...             ...     ...      ...   ...     ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0    82.0   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    75.0   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    73.0   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    87.0   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    84.0   231.0
#
#                College     Salary  height_cm
# ...

# %% [markdown]
# 4. Is there a correlation between height and weight ? Yes

# %%
import pandas as pd 
  
# Making data frame from the csv file 
df = pd.read_csv("nba-player-stats.csv") 
  
# Printing the first 10 rows of the data frame for visualization 
df[:10]
# Out:
#             Name            Team  Number Position   Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    74.0   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    78.0   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    77.0   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    77.0   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0    82.0   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    81.0   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    80.0   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    84.0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    74.0   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    76.0   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
corr1 = df.corr() 
corr1
# Out:
#                      ID  SalePrice  PropertyID  Bedrooms  Bathrooms  \
# ID             1.000000  -0.023166    0.993277 -0.028621  -0.005964
# SalePrice     -0.023166   1.000000   -0.024222  0.319765   0.515982
# PropertyID     0.993277  -0.024222    1.000000 -0.028879  -0.005495
# Bedrooms      -0.028621   0.319765   -0.028879  1.000000   0.534817
# Bathrooms     -0.005964   0.515982   -0.005495  0.534817   1.000000
# SqFtTotLiving -0.017379   0.682573   -0.017396  0.618345   0.749759
# SqFtLot       -0.112888   0.142038   -0.108976  0.079361   0.103723
# YrBuilt        0.028971   0.077967    0.029914  0.139392   0.487521
# ZipCode       -0.007533  -0.024741   -0.011188 -0.031566  -0.233686
#
#                SqFtTotLiving   SqFtLot   YrBuilt   ZipCode
# ID                 -0.017379 -0.112888  0.028971 -0.007533
# SalePrice           0.682573  0.142038  0.077967 -0.024741
# PropertyID         -0.017396 -0.108976  0.029914 -0.011188
# ...

# %% [markdown]
# 5. Create a plot to illustrate the relationship

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(corr1, annot=True)
plt.show()

# %% [markdown]
# EX-4 - Correlation Matrix for House Sales Data

# %% [markdown]
# 1. Read house-sales.csv

# %%
df = pd.read_csv("house-sales-simplified.csv")
df
# Out:
#           ID      Date  SalePrice  PropertyID   PropertyType  Bedrooms  \
# 0          1   9/16/14     280000     1000102      Multiplex         6
# 1          2   6/16/06    1000000     1200013  Single Family         4
# 2          3   1/29/07     745000     1200019  Single Family         4
# 3          4   2/25/08     425000     2800016  Single Family         5
# 4          5   3/29/13     240000     2800024  Single Family         4
# ...      ...       ...        ...         ...            ...       ...
# 27058  27059  10/31/12     374000  9895000030      Townhouse         2
# 27059  27060   12/7/12     374000  9895000040      Townhouse         2
# 27060  27061    7/9/12     165000  9899200010  Single Family         4
# 27061  27062   5/26/06     315000  9900000355  Single Family         3
# 27062  27063    1/9/07     465000  9906000035  Single Family         3
#
#        Bathrooms  SqFtTotLiving  SqFtLot  YrBuilt  ZipCode
# ...

# %% [markdown]
# 2. Create a correlation matrix for this data

# %%
corr2 = df.corr()
corr2
# Out:
#                      ID  SalePrice  PropertyID  Bedrooms  Bathrooms  \
# ID             1.000000  -0.023166    0.993277 -0.028621  -0.005964
# SalePrice     -0.023166   1.000000   -0.024222  0.319765   0.515982
# PropertyID     0.993277  -0.024222    1.000000 -0.028879  -0.005495
# Bedrooms      -0.028621   0.319765   -0.028879  1.000000   0.534817
# Bathrooms     -0.005964   0.515982   -0.005495  0.534817   1.000000
# SqFtTotLiving -0.017379   0.682573   -0.017396  0.618345   0.749759
# SqFtLot       -0.112888   0.142038   -0.108976  0.079361   0.103723
# YrBuilt        0.028971   0.077967    0.029914  0.139392   0.487521
# ZipCode       -0.007533  -0.024741   -0.011188 -0.031566  -0.233686
#
#                SqFtTotLiving   SqFtLot   YrBuilt   ZipCode
# ID                 -0.017379 -0.112888  0.028971 -0.007533
# SalePrice           0.682573  0.142038  0.077967 -0.024741
# PropertyID         -0.017396 -0.108976  0.029914 -0.011188
# ...

# %% [markdown]
# 3. Analyze which attributes affect Saleprice

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(corr2, annot=True)
plt.show()
